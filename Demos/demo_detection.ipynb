# %% [markdown]
# # Demo for Real Time Gait Asymmetry Detection Model Task

# %% [markdown]
# The current notebook is going to be a demo of the real time asymmetry detection model capabilities, while also being used as the initial steps for the creation of the pipeline of the deployed version.

# %%
# Import Liraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time, sys, joblib
from datetime import datetime, timedelta
import demo_support_functions
sys.path.insert(0, '..')

# %% [markdown]
# ### Synthetic Gyroscope Signal Generator: `generate_gait_gyro_signals`
#
# ### Functionality Overview
# The function simulates either a **healthy** or a **stroke-impaired** gait cycle by producing periodic sine wave signals with added noise and frequency/amplitude modulation differences between the left and right shank.
#
# #### Parameters
# - `signal_type` (**str**):
#   - `'healthy'` – symmetrical, clean sinusoidal gait with slight noise.
#   - `'stroke'`  – asymmetrical gait with amplitude/frequency distortion and higher noise.
# - `duration` (**int**): Duration of the simulated signal in **seconds** (default = `100`).
# - `fs` (**int**):  Sampling frequency in **Hz** (default = `100`).
# - `start_time` (**datetime**, optional): The starting timestamp of the signal. If not provided, it defaults to the current time.
#
# #### Signal Characteristics
# - **Healthy Subject:**
#   - Symmetrical sine waves for left and right shanks.
#   - Fixed stride frequency (`1 Hz`) and high amplitudes (≈400 deg/s).
#   - Phase offset (`π`) to mimic left-right alternation.
#   - Light Gaussian noise (σ ≈ 20).
#
# - **Stroke Subject:**
#   - Asymmetrical amplitude: reduced left shank power (≈250 deg/s).
#   - Frequency modulation introduces irregular cadence.
#   - Higher noise on both sides to simulate instability.
#   - Phase offset and distortions reflect gait irregularities.

# %%
def generate_realistic_gait_signal_with_real_noise(left_real_noise, right_real_noise, signal_type='healthy', duration=10, fs=100, random_seed=None):
    if random_seed is not None:
        np.random.seed(random_seed)

    n_samples = int(duration * fs)
    t = np.arange(n_samples) / fs
    timestamps = [datetime.now() + timedelta(seconds=float(i/fs)) for i in range(n_samples)]

    if signal_type == 'healthy':
        amp_right = np.random.normal(400, 40, size=n_samples)
        amp_left = np.random.normal(380, 40, size=n_samples)
        base_freq = 1.0
        phase_jitter = np.random.normal(np.pi, 0.05, size=n_samples)
    elif signal_type == 'stroke':
        amp_right = np.random.normal(300, 50, size=n_samples)
        amp_left = np.random.normal(200, 50, size=n_samples)
        base_freq = 0.9
        phase_jitter = np.random.normal(np.pi * 0.8, 0.1, size=n_samples)
    else:
        raise ValueError("signal_type must be 'healthy' or 'stroke'")

    freq_mod = 0.1 * np.sin(0.05 * t)
    stride   = 2 * np.pi * (base_freq + freq_mod) * t

    right_clean = amp_right * np.sin(stride)
    left_clean  = amp_left * np.sin(stride + phase_jitter)

    right_noise = demo_support_functions.sample_noise(right_real_noise, n_samples)
    left_noise  =  demo_support_functions.sample_noise(left_real_noise, n_samples)

    right_signal = right_clean + right_noise
    left_signal  = left_clean + left_noise

    return pd.DataFrame({
        'timestamp (+0700)': timestamps,
        'left-z-axis (deg/s)': left_signal,
        'right-z-axis (deg/s)': right_signal
    })

# %%
def plot_gyro_signals(df, signal_type='healthy'):
    """
    Plot left and right Z-axis gyroscope signals from a DataFrame.
    
    Parameters:
        df (pd.DataFrame): DataFrame with 'timestamp (+0700)', 
                           'left-z-axis (deg/s)', and 'right-z-axis (deg/s)'
        signal_type (str): 'healthy' or 'stroke' to annotate the title
    """
    plt.figure(figsize=(18, 6))
    
    # Compute elapsed time in seconds
    elapsed_time = (df['timestamp (+0700)'] - df['timestamp (+0700)'].iloc[0]).dt.total_seconds()
    
    plt.plot(elapsed_time, df['right-z-axis (deg/s)'], label='Right Shank - Gyro Z')
    plt.plot(elapsed_time, df['left-z-axis (deg/s)'], label='Left Shank - Gyro Z')
    
    plt.xlabel("Elapsed Time (s)")
    plt.ylabel("Angular Velocity (deg/s)")
    plt.title(f"Gyroscope Z-Axis Comparison: Left vs. Right Shank - {signal_type.capitalize()} Subject")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Load the best performing model for the moderate label

# %%
# Load the model and the scaler
model = joblib.load('/Users/stamatiosorphanos/Documents/GaitRehab/models/detection/random_forest_low_conf.pkl')
scaler = joblib.load('/Users/stamatiosorphanos/Documents/GaitRehab/models/detection/random_forest_low_conf_scaler.pkl')

print('Input features:', model.n_features_in_)
print('Classes:', model.classes_)
# Out:
# Input features: 4
# Classes: [0 1]

# %% [markdown]
# ### Stroke Subject Demo

# %%
# Step 1: Load your raw gyroscope CSV
gyro_df = pd.read_csv('stroke_gyroscope_noise_sample.csv')

# Step 2: Extract real noise vectors
left_real_noise, right_real_noise = demo_support_functions.extract_real_imu_noise(gyro_df)

# Generate synthetic signal
df_stroke = generate_realistic_gait_signal_with_real_noise(left_real_noise, right_real_noise, signal_type='stroke', duration=5, fs=100, random_seed=26)
print('\nRaw data: \n', df_stroke)

# Extract the features by the synthetic signal
features = demo_support_functions.extract_features_per_gait_cycle(df_stroke)
y = len(features) * [0]

# Use scaler to transform data
X_df = pd.DataFrame(features)[model.feature_names_in_]
X_scaled = scaler.transform(X_df)
print('\nFeatures scaled from features: \n', X_scaled)


# Get the predictions and the respective probabilities 
y_preds = model.predict(X_scaled)
y_probs = model.predict_proba(X_scaled)

print('\n')
for i, (label, prob) in enumerate(zip(y_preds, y_probs)):
    print(f'Cycle {i+1}: Prediction = {label}, Probabilities = {prob}')


# Plot the stroke synthetic signal
plot_gyro_signals(df_stroke, signal_type='stroke')
# Out:
# Raw data:
#               timestamp (+0700)  left-z-axis (deg/s)  right-z-axis (deg/s)
# 0   2025-06-26 15:18:23.181048            89.506066              4.023844
# 1   2025-06-26 15:18:23.191055           104.288105              8.228790
# 2   2025-06-26 15:18:23.201056            31.126344             41.634868
# 3   2025-06-26 15:18:23.211057            84.557288             53.741736
# 4   2025-06-26 15:18:23.221058            45.706457             66.444927
# ..                         ...                  ...                   ...
# 495 2025-06-26 15:18:28.131405           -54.151039           -180.153287
# 496 2025-06-26 15:18:28.141405             4.201101           -186.163580
# 497 2025-06-26 15:18:28.151406             0.793143           -232.049119
# 498 2025-06-26 15:18:28.161407             1.417153           -217.266733
# 499 2025-06-26 15:18:28.171407            33.811191           -203.142740
#
# [500 rows x 3 columns]
#
# Features scaled from features:
# ...
